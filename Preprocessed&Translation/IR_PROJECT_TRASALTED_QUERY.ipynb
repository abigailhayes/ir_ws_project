# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import numpy as np
import sys
import os
import pandas as pd
import string
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import *

# %%
import pandas as pd

read_file = pd.read_excel('(usingGoogle)final_query_translated.xlsx', engine='openpyxl')
# read_file.to_csv (r'Dataset_A.csv', index = None, header=True)

# %%
read_file
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
df2= pd.read_json("livivo_hq_test_100_candidates.jsonl",lines=True)

# %%
df=pd.DataFrame(read_file)
# df['ABSTRACT']=df['ABSTRACT'].fillna("").apply(list)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def list_to_string(text):
    abc=''.join(text)
   
    return abc

# %%
df['Preprocessing'] = df['qstr_en'].apply(list_to_string)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def lower_text(text):
    text=text.lower()
    return text

# %%
df['Preprocessing'] = df['Preprocessing'].apply(lower_text)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
df['Preprocessing'] = df['Preprocessing'].apply(remove_punctuations)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def remove_AND_OR(text):
    text=text.replace(' and', '  ')
    text=text.replace(' or', '  ')
    return text

# %%
df['Preprocessing'] = df['Preprocessing'].apply(remove_AND_OR)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
df.tail(36)
# Out:
#     Unnamed: 0  qid:                                     qstr  \
# 64          64  1132                          implementierung
# 65          65   679                                  weaning
# 66          66  1338   interprofessionelle AND zusammenarbeit
# 67          67   836  kommunikation AND in AND der AND pflege
# 68          68  1115  patientenzufriedenheit AND mammaplastik
# 69          69  1390                                   visite
# 70          70   774                 gesundheitskommunikation
# 71          71  1092                     alzheimer AND demenz
# 72          72  1186                                      dmp
# 73          73   817                             telemedicine
# 74          74   474                            prostatakrebs
# 75          75   738                      peripherer AND nerv
# 76          76  1096                                  fatique
# 77          77   418                                    ebola
# ...

# %%
def double_space(text):
    for i in range(0, len(text)):
        text= text.replace(' +', ' ')
    return text

# %%
df["Preprocessing"] = df['Preprocessing'].apply(double_space)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def remove_special(text):
    ls=[]
    for k in text.split("\n"):
        ls.append(re.sub(r"[^a-zA-Z0-9]+", ' ', k))
    text= " ".join(ls)
    return text

# %%
df["Preprocessing"] = df['Preprocessing'].apply(remove_special)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
df["Preprocessing"] = df['Preprocessing'].apply(nltk.word_tokenize)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def Stopwords(text):
    stop_words = stopwords.words('english')
    word_tokens = [t for t in text if not (t in stop_words)]
    return word_tokens

# %%
df["Preprocessing"] = df['Preprocessing'].apply(Stopwords)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
def stemming(text):
    ps = PorterStemmer()
    stems=[]
    for i in text:
        stems.append(ps.stem(i))
    return stems

# %%
df["Preprocessing"] = df['Preprocessing'].apply(stemming)

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %% [markdown]
# ## Change columm name

# %%
df["Preprocessed_Query"] = df['Preprocessing']

# %%
df
# Out:
#     Unnamed: 0  qid:             qstr  \
# 0            0   943             mbsr
# 1            1   925           gender
# 2            2   407       einsamkeit
# 3            3   123          midwife
# 4            4   220              bgm
# ..         ...   ...              ...
# 95          95   374  intensivstation
# 96          96   264   rettungsdienst
# 97          97   791       ausbildung
# 98          98   399        safewards
# 99          99  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# 2   ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de
# 3   ['M18612453', 'M32361389', 'M33000708', 'M3353...       en
# 4   ['M33384475', 'M33392927', 'M33634364', 'M3217...       en
# ..                                                ...      ...
# ...

# %%
first_column = df.pop('Preprocessed_Query')
df.insert(1, 'Preprocessed_Query',first_column)
df
# Out:
#     Unnamed: 0    Preprocessed_Query  qid:             qstr  \
# 0            0                [mbsr]   943             mbsr
# 1            1              [gender]   925           gender
# 2            2               [lonli]   407       einsamkeit
# 3            3              [midwif]   123          midwife
# 4            4                 [bgm]   220              bgm
# ..         ...                   ...   ...              ...
# 95          95  [intens, care, unit]   374  intensivstation
# 96          96       [rescu, servic]   264   rettungsdienst
# 97          97               [train]   791       ausbildung
# 98          98            [safeward]   399        safewards
# 99          99           [low, carb]  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# ...

# %%
df
# Out:
#     Unnamed: 0    Preprocessed_Query  qid:             qstr  \
# 0            0                [mbsr]   943             mbsr
# 1            1              [gender]   925           gender
# 2            2               [lonli]   407       einsamkeit
# 3            3              [midwif]   123          midwife
# 4            4                 [bgm]   220              bgm
# ..         ...                   ...   ...              ...
# 95          95  [intens, care, unit]   374  intensivstation
# 96          96       [rescu, servic]   264   rettungsdienst
# 97          97               [train]   791       ausbildung
# 98          98            [safeward]   399        safewards
# 99          99           [low, carb]  1172     low AND carb
#
#                                            candidates qstr_lan  \
# 0   ['M30928765', 'M30928764', 'M33155250', 'M3013...       en
# 1   ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en
# ...

# %%
df.to_csv('PPTranslatedQueryWithStem.csv')
