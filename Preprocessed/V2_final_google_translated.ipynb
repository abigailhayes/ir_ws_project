# %%
import re
import numpy as np
import sys
import os
import pandas as pd
import string
import matplotlib.pyplot as plt 
import re
from tqdm import tqdm

import googletrans
from googletrans import Translator

translator = Translator()
text2 = "Die Vorlesung über Suchmaschinen ist großartig!"
print(translator.detect(text2))
print(translator.translate(text2))
# Out:
# Detected(lang=de, confidence=None)
# Translated(src=de, dest=en, text=The lecture on search engines is great!, pronunciation=None, extra_data="{'confiden...")

# %%
document= pd.read_csv("PPTranslatedAbstract_Title.csv")
query = pd.read_csv("PPTranslatedQuery.csv")

# %%
document.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                Preprocessed_Abstract  \
# 0  ['the', 'paper', 'begins', 'with', 'a', 'brief...
# 1  ['this', 'paper', 'is', 'a', 'response', 'to',...
# 2  ['objectivethis', 'study', 'aims', 'to', 'surv...
# 3  ['genetic', 'variations', 'of', 'breast', 'can...
# 4  ['backgroundmindfulnessbased', 'programs', 'ha...
#
#                                   Preprocessed_Title  Unnamed: 0.1  qid:  \
# 0  ['the', 'beauty', 'we', 'love', 'mbsr', 'teach...             0   943
# 1  ['building', 'an', 'ark', 'creating', 'a', 've...             1   943
# 2  ['the', 'use', 'of', 'online', 'mbsr', 'audio'...             2   943
# 3  ['translational', 'genomic', 'research', 'the'...             3   943
# 4  ['the', 'effect', 'of', 'mindfulnessbased', 's...             4   943
#
#    qstr candidates DBRECORDID  \
# 0  mbsr  M30928765  M30928765
# 1  mbsr  M30928764  M30928764
# 2  mbsr  M33155250  M33155250
# 3  mbsr  M30137607  M30137607
# 4  mbsr  M32848377  M32848377
#
#                                                TITLE  ... PUBLPLACE  \
# 0  ['The beauty we love: MBSR teacher education g...  ...       NaN
# 1  ['Building an ark: creating a vessel for the e...  ...       NaN
# 2  ['The use of online MBSR audio in medical staf...  ...       NaN
# 3  ['Translational genomic research: the role of ...  ...       NaN
# 4  ['The Effect of Mindfulness-Based Stress Reduc...  ...       NaN
#
#   INSTITUTION                                             TITLE_  \
# 0         NaN  The beauty we love MBSR teacher education goin...
# 1         NaN  Building an ark creating a vessel for the educ...
# 2         NaN  The use of online MBSR audio in medical staff ...
# 3         NaN  Translational genomic research the role of gen...
# 4         NaN  The Effect of MindfulnessBased Stress Reductio...
#
#                                            ABSTRACT_ TITLE_lan ABSTRACT_lan  \
# 0  The paper begins with a brief overview of the ...        en           en
# 1  This paper is a response to an invitation by t...        en           en
# 2  ObjectiveThis study aims to survey medical sta...        en           en
# 3  Genetic variations of breast cancer survivors ...        en           en
# 4  BackgroundMindfulnessbased programs have shown...        en           en
#
#                                             title_en  \
# 0  The beauty we love MBSR teacher education goin...
# 1  Building an ark creating a vessel for the educ...
# 2  The use of online MBSR audio in medical staff ...
# 3  Translational genomic research the role of gen...
# 4  The Effect of MindfulnessBased Stress Reductio...
#
#                                          abstract_en TITLE_lan code(memo)  \
# 0  The paper begins with a brief overview of the ...                  NaN
# 1  This paper is a response to an invitation by t...                  NaN
# 2  ObjectiveThis study aims to survey medical sta...                  NaN
# 3  Genetic variations of breast cancer survivors ...                  NaN
# 4  BackgroundMindfulnessbased programs have shown...                  NaN
#
#   ABSTRACT_lan code(memo)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 40 columns]

# %%
query.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 Preprocessed_Query  qid:        qstr  \
# 0             0           0           ['mbsr']   943        mbsr
# 1             1           1         ['gender']   925      gender
# 2             2           2      ['lonliness']   407  einsamkeit
# 3             3           3        ['midwife']   123     midwife
# 4             4           4            ['bgm']   220         bgm
#
#                                           candidates qstr_lan    qstr_en  \
# 0  ['M30928765', 'M30928764', 'M33155250', 'M3013...       en       mbsr
# 1  ['M32275910', 'NLM101312283', 'M10231258', 'M3...       en     gender
# 2  ['NLM9707686', 'NLM9215358', 'M27924693', 'M33...       de  lonliness
# 3  ['M18612453', 'M32361389', 'M33000708', 'M3353...       en    midwife
# 4  ['M33384475', 'M33392927', 'M33634364', 'M3217...       en        bgm
#
#   Language(memo)  Preprocessing
# 0            NaN       ['mbsr']
# 1            NaN     ['gender']
# 2            NaN  ['lonliness']
# 3            NaN    ['midwife']
# 4            NaN        ['bgm']

# %%
# checking if the num of candidates is 10000(100*100)
print(sum([len(query['candidates'][i].split('\', \'')) for i in range(100)]))
# Out:
# 10000

# %%
def remove_special(x):
    x = x.replace("[", "").replace("]","").replace("\'","").replace(" ","")
    return x

query['candidates_'] = [remove_special(x).split(',') for x in query['candidates']]

merged_df = document.merge(query.explode("candidates_"), how='left', left_on=('candidates','qid:'), right_on=('candidates_','qid:'))

# %%
new_title= []
for i in tqdm(range(merged_df.shape[0])):
    try:
        new_title.append(translator.translate(merged_df['TITLE_'][i],  src=merged_df['TITLE_lan'][i], dest=merged_df['qstr_lan'][i]).text)
    except:
        new_title.append(merged_df['TITLE_'][i])
# Out:
# 100%|██████████| 10000/10000 [1:11:21<00:00,  2.34it/s]

# %%
query['new_title']=new_title
query
#new_title.to_csv("new_title.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 query['new_title']=new_title
#       2 query
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (10000) does not match length of index (100)

# %%
new_abstract= []
for i in tqdm(range(merged_df.shape[0])):
    try:
        new_title.append(translator.translate(merged_df['ABSTRACT_'][i],  src=merged_df['ABSTRACT_lan'][i], dest=merged_df['qstr_lan'][i]).text)
    except:
        new_title.append(merged_df['ABSTRACT_'][i])
